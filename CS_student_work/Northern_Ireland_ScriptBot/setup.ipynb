# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %%bash
# # ---- fast-restore venv ----
# VENV=/content/ni_bot_venv
# REQS=/content/drive/MyDrive/Northern_Ireland_ScriptBot/requirements.txt
#
# if [ ! -d "$VENV" ]; then
#   echo "First run in this VM – building venv..."
#   python -m venv "$VENV"
#   "$VENV/bin/pip" install -U pip
#   "$VENV/bin/pip" install -r "$REQS"
# fi
#
# source "$VENV/bin/activate"
# echo "✓  venv ready at $VENV"
# Out:
# First run in this VM – building venv...
# ✓  venv ready at /content/ni_bot_venv
# Error: Command '['/content/ni_bot_venv/bin/python3', '-m', 'ensurepip', '--upgrade', '--default-pip']' returned non-zero exit status 1.
# bash: line 8: /content/ni_bot_venv/bin/pip: No such file or directory
# bash: line 9: /content/ni_bot_venv/bin/pip: No such file or directory
# bash: line 12: /content/ni_bot_venv/bin/activate: No such file or directory

# %%
cd /content
# Out:
# /content

# %%
# Out:
# /root
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-138de98fdde5> in <cell line: 0>()
#       4 nb = _message.blocking_request('get_ipynb', timeout_sec=5)
#       5
# ----> 6 print(nb['metadata']['colab']['name'])
#
# KeyError: 'metadata'
